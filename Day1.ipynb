# %% [raw]
# RAINBOW

# %%
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
cost_price = float(input())
sell_price = float(input())

if cost_price < sell_price:
    print("Profit")
elif cost_price > sell_price:
    print("Loss")
else:
    print("Neither")
# Out:
# 20
# 10
# Loss

# %%
amount_euros = int(input())
amount_rupees = amount_euros * 80;
print(amount_rupees)
# Out:
# 20
# 1600
